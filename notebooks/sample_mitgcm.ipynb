# %% [markdown]
# # Imports

# %%
# System imports
import os
import sys
import warnings
warnings.filterwarnings(action='ignore')

# Data handling
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt
from IPython.display import Video, Image, HTML, display

# %% [markdown]
# # Read in data

# %%
MITGCM_filename = "../../data/raw/cat_tave.nc"
ds = xr.open_dataset(MITGCM_filename)
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (T: 18000, Y: 78, X: 11, Z: 42, Xp1: 12, Yp1: 79, Zl: 42,
#                   Zld000042: 42, Zmd000042: 42)
# Coordinates:
#   * T            (T) float64 1.555e+09 1.555e+09 1.555e+09 ... 3.11e+09 3.11e+09
#   * X            (X) float64 1.0 3.0 5.0 7.0 9.0 11.0 13.0 15.0 17.0 19.0 21.0
#   * Xp1          (Xp1) float64 0.0 2.0 4.0 6.0 8.0 ... 14.0 16.0 18.0 20.0 22.0
#   * Y            (Y) float64 -59.5 -58.48 -57.44 -56.36 ... 58.48 59.5 60.5 61.5
#   * Yp1          (Yp1) float64 -60.0 -59.0 -57.97 -56.91 ... 59.0 60.0 61.0 62.0
#   * Z            (Z) float64 -5.0 -15.05 -25.25 ... -4.625e+03 -4.875e+03
#   * Zl           (Zl) float64 0.0 -10.0 -20.1 ... -4.25e+03 -4.5e+03 -4.75e+03
# Dimensions without coordinates: Zld000042, Zmd000042
# Data variables: (12/23)
#     ETAtave      (T, Y, X) float32 ...
#     Stave        (T, Z, Y, X) float32 ...
#     Ttave        (T, Z, Y, X) float32 ...
#     uVeltave     (T, Z, Y, Xp1) float32 ...
# ...

# %%
# Pick some random temperature values
np.random.seed(2023)
random_T_vals = np.random.choice(ds.T, size=100, replace=False)
random_T_vals
# Out:
# array([2.1420288e+09, 2.0189088e+09, 1.7498592e+09, 1.7051040e+09,
#        2.0215872e+09, 1.9137600e+09, 1.6601760e+09, 2.4087456e+09,
#        2.4168672e+09, 2.0375712e+09, 2.9482272e+09, 1.6818624e+09,
#        1.8179424e+09, 2.5634880e+09, 2.3056704e+09, 2.1516192e+09,
#        2.1989664e+09, 2.6946432e+09, 3.0682368e+09, 2.1303648e+09,
#        2.7599616e+09, 2.7256608e+09, 2.9256768e+09, 2.3140512e+09,
#        2.9128896e+09, 2.1282048e+09, 2.3909472e+09, 2.7388800e+09,
#        1.5834528e+09, 2.2460544e+09, 1.7165952e+09, 2.7942624e+09,
#        2.0488032e+09, 2.5578720e+09, 2.9057184e+09, 2.3131872e+09,
#        2.4751872e+09, 1.6714080e+09, 2.5723872e+09, 2.3092128e+09,
#        1.6715808e+09, 1.6171488e+09, 2.6130816e+09, 1.8698688e+09,
#        2.0074176e+09, 2.4798528e+09, 2.4597216e+09, 2.2086432e+09,
#        2.4806304e+09, 2.1966336e+09, 2.6885952e+09, 2.1225024e+09,
#        2.5074144e+09, 2.8524096e+09, 3.0759264e+09, 1.7762112e+09,
# ...

# %%
# Slice the Dataset using the random picks
ds_sample = ds.sel(T=random_T_vals, method="nearest")
ds_sample
# Out:
# <xarray.Dataset>
# Dimensions:      (T: 100, Y: 78, X: 11, Z: 42, Xp1: 12, Yp1: 79, Zl: 42,
#                   Zld000042: 42, Zmd000042: 42)
# Coordinates:
#   * T            (T) float64 2.142e+09 2.019e+09 ... 2.475e+09 3.055e+09
#   * X            (X) float64 1.0 3.0 5.0 7.0 9.0 11.0 13.0 15.0 17.0 19.0 21.0
#   * Xp1          (Xp1) float64 0.0 2.0 4.0 6.0 8.0 ... 14.0 16.0 18.0 20.0 22.0
#   * Y            (Y) float64 -59.5 -58.48 -57.44 -56.36 ... 58.48 59.5 60.5 61.5
#   * Yp1          (Yp1) float64 -60.0 -59.0 -57.97 -56.91 ... 59.0 60.0 61.0 62.0
#   * Z            (Z) float64 -5.0 -15.05 -25.25 ... -4.625e+03 -4.875e+03
#   * Zl           (Zl) float64 0.0 -10.0 -20.1 ... -4.25e+03 -4.5e+03 -4.75e+03
# Dimensions without coordinates: Zld000042, Zmd000042
# Data variables: (12/23)
#     ETAtave      (T, Y, X) float32 ...
#     Stave        (T, Z, Y, X) float32 ...
#     Ttave        (T, Z, Y, X) float32 ...
#     uVeltave     (T, Z, Y, Xp1) float32 ...
# ...

# %%
# Save to disk
dirname = os.path.dirname(MITGCM_filename)
basename = os.path.basename(MITGCM_filename)
savename = os.path.join(dirname, f"sample_{basename}")
ds_sample.to_netcdf(savename)
